# %% [markdown]
# <a href="https://colab.research.google.com/github/Somrat390/NLP/blob/main/Part_of_Speech_Tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part of Speech in Spacy

# %%
# !pip install -q spacy

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('Elon flew to mars yesterday. He carried biryani masala with him or')

for token in doc:
  print(token, ' | ', token.pos_, ' | ', spacy.explain(token.pos_))
# Out:
# Elon  |  PROPN  |  proper noun
# flew  |  VERB  |  verb
# to  |  ADP  |  adposition
# mars  |  NOUN  |  noun
# yesterday  |  NOUN  |  noun
# .  |  PUNCT  |  punctuation
# He  |  PRON  |  pronoun
# carried  |  VERB  |  verb
# biryani  |  ADJ  |  adjective
# masala  |  NOUN  |  noun
# with  |  ADP  |  adposition
# him  |  PRON  |  pronoun
# or  |  CCONJ  |  coordinating conjunction

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp('Elon flew to mars yesterday. He carried biryani masala with him or')

for token in doc:
  print(token, ' | ', token.pos_, ' | ', spacy.explain(token.pos_), ' | ', token.tag_, ' | ', spacy.explain(token.tag_))
# Out:
# Elon  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# flew  |  VERB  |  verb  |  VBD  |  verb, past tense
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# mars  |  NOUN  |  noun  |  NNS  |  noun, plural
# yesterday  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# He  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# carried  |  VERB  |  verb  |  VBD  |  verb, past tense
# biryani  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# masala  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# with  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# him  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# or  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating

# %%
doc = nlp('He quits his job')

print(doc[1].text, ' | ', doc[1].tag_, ' | ', spacy.explain(doc[1].tag_))
# Out:
# quits  |  VBZ  |  verb, 3rd person singular present

# %%
earning_text = """REDMOND, Wash. — July 29, 2026 — Microsoft Corp. today announced the following results for the quarter ended June 30, 2026, as compared to the corresponding period of last fiscal year:

·        Revenue was $90.0 billion and increased 18% (up 17% in constant currency)

·        Operating income was $40.6 billion and increased 18%

·        Net income was $35.8 billion and increased 31% on a GAAP basis, and was $35.3 billion and increased 22% on a non-GAAP basis

·        Diluted earnings per share was $4.81 and increased 32% on a GAAP basis, and was $4.74 and increased 23% on a non-GAAP basis

·        Non-GAAP results exclude the impact from investments in OpenAI, explained in the Non-GAAP Definition section below

Several discrete items impacted our financial results in the quarter when compared to our forward-looking guidance provided on April 29, 2026, resulting in a benefit of $0.27 on diluted earnings per share. These include a $3.2 billion gain from our investment in Anthropic and lower-than-expected expenses related to the Voluntary Retirement Program which were partially offset by severance expense and impairment charges in XBOX. When adjusting for these items, we exceeded expectations across revenue, operating income, and diluted earnings per share."""

# %%
doc = nlp(earning_text)

for token in doc:
  print(token.text, ' | ', token.pos_)
# Out:
# REDMOND  |  PROPN
# ,  |  PUNCT
# Wash.  |  PROPN
# —  |  PUNCT
# July  |  PROPN
# 29  |  NUM
# ,  |  PUNCT
# 2026  |  NUM
# —  |  PUNCT
# Microsoft  |  PROPN
# Corp.  |  PROPN
# today  |  NOUN
# announced  |  VERB
# the  |  DET
# following  |  VERB
# results  |  NOUN
# for  |  ADP
# the  |  DET
# quarter  |  NOUN
# ended  |  VERB
# June  |  PROPN
# 30  |  NUM
# ,  |  PUNCT
# 2026  |  NUM
# ,  |  PUNCT
# as  |  SCONJ
# compared  |  VERB
# to  |  ADP
# the  |  DET
# corresponding  |  ADJ
# period  |  NOUN
# of  |  ADP
# last  |  ADJ
# fiscal  |  ADJ
# year  |  NOUN
# :  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# Revenue  |  NOUN
# was  |  AUX
# $  |  SYM
# 90.0  |  NUM
# billion  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 18  |  NUM
# %  |  NOUN
# (  |  PUNCT
# up  |  ADV
# 17  |  NUM
# %  |  NOUN
# in  |  ADP
# constant  |  ADJ
# currency  |  NOUN
# )  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# Operating  |  VERB
# income  |  NOUN
# was  |  AUX
# $  |  SYM
# 40.6  |  NUM
# billion  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 18  |  NUM
# %  |  NOUN
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# Net  |  ADJ
# income  |  NOUN
# was  |  AUX
# $  |  SYM
# 35.8  |  NUM
# billion  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 31  |  NUM
# %  |  NOUN
# on  |  ADP
# a  |  DET
# GAAP  |  NOUN
# basis  |  NOUN
# ,  |  PUNCT
# and  |  CCONJ
# was  |  AUX
# $  |  SYM
# 35.3  |  NUM
# billion  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 22  |  NUM
# %  |  NOUN
# on  |  ADP
# a  |  DET
# non  |  ADJ
# -  |  NOUN
# GAAP  |  NOUN
# basis  |  NOUN
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# Diluted  |  VERB
# earnings  |  NOUN
# per  |  ADP
# share  |  NOUN
# was  |  AUX
# $  |  SYM
# 4.81  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 32  |  NUM
# %  |  NOUN
# on  |  ADP
# a  |  DET
# GAAP  |  NOUN
# basis  |  NOUN
# ,  |  PUNCT
# and  |  CCONJ
# was  |  AUX
# $  |  SYM
# 4.74  |  NUM
# and  |  CCONJ
# increased  |  VERB
# 23  |  NUM
# %  |  NOUN
# on  |  ADP
# a  |  DET
# non  |  ADJ
# -  |  NOUN
# GAAP  |  NOUN
# basis  |  NOUN
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# Non  |  NOUN
# -  |  NOUN
# GAAP  |  NOUN
# results  |  NOUN
# exclude  |  VERB
# the  |  DET
# impact  |  NOUN
# from  |  ADP
# investments  |  NOUN
# in  |  ADP
# OpenAI  |  PROPN
# ,  |  PUNCT
# explained  |  VERB
# in  |  ADP
# the  |  DET
# Non  |  PROPN
# -  |  PROPN
# GAAP  |  NOUN
# Definition  |  PROPN
# section  |  NOUN
# below  |  ADP
#
#
#   |  SPACE
# Several  |  ADJ
# discrete  |  ADJ
# items  |  NOUN
# impacted  |  VERB
# our  |  PRON
# financial  |  ADJ
# results  |  NOUN
# in  |  ADP
# the  |  DET
# quarter  |  NOUN
# when  |  SCONJ
# compared  |  VERB
# to  |  ADP
# our  |  PRON
# forward  |  ADV
# -  |  PUNCT
# looking  |  VERB
# guidance  |  NOUN
# provided  |  VERB
# on  |  ADP
# April  |  PROPN
# 29  |  NUM
# ,  |  PUNCT
# 2026  |  NUM
# ,  |  PUNCT
# resulting  |  VERB
# in  |  ADP
# a  |  DET
# benefit  |  NOUN
# of  |  ADP
# $  |  SYM
# 0.27  |  NUM
# on  |  ADP
# diluted  |  ADJ
# earnings  |  NOUN
# per  |  ADP
# share  |  NOUN
# .  |  PUNCT
# These  |  PRON
# include  |  VERB
# a  |  DET
# $  |  SYM
# 3.2  |  NUM
# billion  |  NUM
# gain  |  NOUN
# from  |  ADP
# our  |  PRON
# investment  |  NOUN
# in  |  ADP
# Anthropic  |  PROPN
# and  |  CCONJ
# lower  |  ADJ
# -  |  PUNCT
# than  |  ADP
# -  |  PUNCT
# expected  |  VERB
# expenses  |  NOUN
# related  |  VERB
# to  |  ADP
# the  |  DET
# Voluntary  |  PROPN
# Retirement  |  PROPN
# Program  |  PROPN
# which  |  PRON
# were  |  AUX
# partially  |  ADV
# offset  |  VERB
# by  |  ADP
# severance  |  ADJ
# expense  |  NOUN
# and  |  CCONJ
# impairment  |  NOUN
# charges  |  NOUN
# in  |  ADP
# XBOX  |  NOUN
# .  |  PUNCT
# When  |  SCONJ
# adjusting  |  VERB
# for  |  ADP
# these  |  DET
# items  |  NOUN
# ,  |  PUNCT
# we  |  PRON
# exceeded  |  VERB
# expectations  |  NOUN
# across  |  ADP
# revenue  |  NOUN
# ,  |  PUNCT
# operating  |  NOUN
# income  |  NOUN
# ,  |  PUNCT
# and  |  CCONJ
# diluted  |  VERB
# earnings  |  NOUN
# per  |  ADP
# share  |  NOUN
# .  |  PUNCT

# %%
doc = nlp(earning_text)

for token in doc:
  if token.pos_ in ['SPACE','X','PUNCT']:
     print(token.text, ' | ', token.pos_)
# Out:
# ,  |  PUNCT
# —  |  PUNCT
# ,  |  PUNCT
# —  |  PUNCT
# ,  |  PUNCT
# ,  |  PUNCT
# :  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# (  |  PUNCT
# )  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# ,  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# ,  |  PUNCT
#
#
#   |  SPACE
# ·  |  PUNCT
#          |  SPACE
# ,  |  PUNCT
#
#
#   |  SPACE
# -  |  PUNCT
# ,  |  PUNCT
# ,  |  PUNCT
# .  |  PUNCT
# -  |  PUNCT
# -  |  PUNCT
# .  |  PUNCT
# ,  |  PUNCT
# ,  |  PUNCT
# ,  |  PUNCT
# .  |  PUNCT

# %%
doc = nlp(earning_text)

filter_tokens = []
for token in doc:
  if token.pos_  not in  ['SPACE','PUNCT']:
     filter_tokens.append(token)

# %%
filter_tokens
# Out:
# [REDMOND,
#  Wash.,
#  July,
#  29,
#  2026,
#  Microsoft,
#  Corp.,
#  today,
#  announced,
#  the,
#  following,
#  results,
#  for,
#  the,
#  quarter,
#  ended,
#  June,
#  30,
#  2026,
#  as,
#  compared,
#  to,
#  the,
#  corresponding,
#  period,
#  of,
#  last,
#  fiscal,
#  year,
#  Revenue,
#  was,
#  $,
#  90.0,
#  billion,
#  and,
#  increased,
#  18,
#  %,
#  up,
#  17,
#  %,
#  in,
#  constant,
#  currency,
#  Operating,
#  income,
#  was,
#  $,
#  40.6,
#  billion,
#  and,
#  increased,
#  18,
#  %,
#  Net,
#  income,
#  was,
#  $,
#  35.8,
#  billion,
#  and,
#  increased,
#  31,
#  %,
#  on,
#  a,
#  GAAP,
#  basis,
#  and,
#  was,
#  $,
#  35.3,
#  billion,
#  and,
#  increased,
#  22,
#  %,
#  on,
#  a,
#  non,
#  -,
#  GAAP,
#  basis,
#  Diluted,
#  earnings,
#  per,
#  share,
#  was,
#  $,
#  4.81,
#  and,
#  increased,
#  32,
#  %,
#  on,
#  a,
#  GAAP,
#  basis,
#  and,
#  was,
#  $,
#  4.74,
#  and,
#  increased,
#  23,
#  %,
#  on,
#  a,
#  non,
#  -,
#  GAAP,
#  basis,
#  Non,
#  -,
#  GAAP,
#  results,
#  exclude,
#  the,
#  impact,
#  from,
#  investments,
#  in,
#  OpenAI,
#  explained,
#  in,
#  the,
#  Non,
#  -,
#  GAAP,
#  Definition,
#  section,
#  below,
#  Several,
#  discrete,
#  items,
#  impacted,
#  our,
#  financial,
#  results,
#  in,
#  the,
#  quarter,
#  when,
#  compared,
#  to,
#  our,
#  forward,
#  looking,
#  guidance,
#  provided,
#  on,
#  April,
#  29,
#  2026,
#  resulting,
#  in,
#  a,
#  benefit,
#  of,
#  $,
#  0.27,
#  on,
#  diluted,
#  earnings,
#  per,
#  share,
#  These,
#  include,
#  a,
#  $,
#  3.2,
#  billion,
#  gain,
#  from,
#  our,
#  investment,
#  in,
#  Anthropic,
#  and,
#  lower,
#  than,
#  expected,
#  expenses,
#  related,
#  to,
#  the,
#  Voluntary,
#  Retirement,
#  Program,
#  which,
#  were,
#  partially,
#  offset,
#  by,
#  severance,
#  expense,
#  and,
#  impairment,
#  charges,
#  in,
#  XBOX,
#  When,
#  adjusting,
#  for,
#  these,
#  items,
#  we,
#  exceeded,
#  expectations,
#  across,
#  revenue,
#  operating,
#  income,
#  and,
#  diluted,
#  earnings,
#  per,
#  share]

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {96: 15,
#  97: 28,
#  93: 26,
#  92: 57,
#  100: 26,
#  90: 14,
#  85: 29,
#  98: 3,
#  84: 13,
#  103: 11,
#  87: 7,
#  99: 8,
#  89: 11,
#  86: 3,
#  95: 6}

# %%
for k,v in count.items():
  print(doc.vocab[k].text, ' | ', v)
# Out:
# PROPN  |  15
# PUNCT  |  28
# NUM  |  26
# NOUN  |  57
# VERB  |  26
# DET  |  14
# ADP  |  29
# SCONJ  |  3
# ADJ  |  13
# SPACE  |  11
# AUX  |  7
# SYM  |  8
# CCONJ  |  11
# ADV  |  3
# PRON  |  6
