# %% [markdown]
# <a href="https://colab.research.google.com/github/Somrat390/NLP/blob/main/Spacy_Preprocessing_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q spacy

# %%
import spacy

nlp = spacy.blank('en')

doc = nlp('I love mango and Ice-cream')

token = [token.text for token in doc]
token
# Out:
# ['I', 'love', 'mango', 'and', 'Ice', '-', 'cream']

# %%
nlp.pipeline
# Out:
# []

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7b93fc44f950>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7b93fc44f9b0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7b93fc441540>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7b93fc20af10>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7b93fc20bc50>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7b93fc441690>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp('I love mango and Ice-cream')

for token in doc:
  print(token , ' | ' ,token.pos_ , ' | ' ,token.lemma_)
# Out:
# I  |  PRON  |  I
# love  |  VERB  |  love
# mango  |  PROPN  |  mango
# and  |  CCONJ  |  and
# Ice  |  PROPN  |  Ice
# -  |  PUNCT  |  -
# cream  |  NOUN  |  cream

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")

for ent in doc.ents:
  print(ent.text, ' | ', ent.label_ , ' | ', spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
source_pipeline = spacy.load('en_core_web_sm')

nlp = spacy.blank('en')
nlp.add_pipe('ner', source=source_pipeline)

doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")

for ent in doc.ents:
  print(ent.text, ' | ', ent.label_ , ' | ', spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit
